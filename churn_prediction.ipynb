# %%
import pandas as pd

# %%
data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#                                            msno  city  bd  gender  \
# 0  stBalzWUP3HmiKPW6PoarmyG6wSnLYUxJzAkj9rNJzw=     5  24  female
# 1  i2B9In7K03UhHtV4PHc0ntP9t9XNfJ+IyCXM8tGy/9A=    13  34  female
# 2  JHIW++D91fUw/0GtCQ7Tsogh8hG5BWvZf0nITnMxT/w=    13  30    male
# 3  x/WBN5eVLWRnZRBGKnUDZRjsK59PiLiVp0+5Dt1GwUg=     6  24  female
# 4  bTplk9So0DEFLPHSxRyI8/vo4P7EBhkxkamyFYjjw68=    16  29  female
#
#    registered_via  registration_init_time  expiration_date      date  num_25  \
# 0               9                20120301         20170911  20160517       0
# 1               9                20060106         20170916  20160108       2
# 2               9                20061024         20170930  20150623       1
# 3               9                20110919         20170222  20160521       9
# 4               3                20120913         20171008  20150521       0
#
#    num_50    ...     total_secs  payment_method_id  payment_plan_days  \
# ...
